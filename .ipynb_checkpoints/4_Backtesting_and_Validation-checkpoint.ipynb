# %% [markdown]
# # Notebook 4: Backtesting and Validation
#
# In this notebook, we evaluate the performance of the trained Deep Hedging model on the test set.
#
# ---
#
# ## Objective
#
# Measure how well the model's hedge strategy replicates the final option payoff, and compare the hedged portfolio value $( V_T )$ with the true payoff $( Z_T )$.
#
# ---
#
# ## 4.1 Load Model Evaluation Results
#
# We load pre-saved test data from:
#
# results/hedging_eval_test.npz
#
# Always show details
#
# It contains:
# - `V_T`: the terminal value of the hedged portfolio
# - `Z_T`: the true payoff of the option (European Call)
#
# ---
#
# ## 4.2 Visualizations
#
# ### Histogram of $( V_T )$ vs $( Z_T )$
#
# - Overlays both the model’s hedged portfolio value and the option payoff.
# - Shows distribution of performance across test paths.
#
# ### Hedging Effectiveness — Scatter / Hexbin Plot
#
# - Each point is a test path:
#   - x-axis: $( Z_T )$ (true payoff)
#   - y-axis: $( V_T )$ (hedged value)
# - The red dashed line represents a perfect hedge (i.e., $( V_T = Z_T )$)
# - A good model should closely hug the diagonal.
#
# ### Hedging Error Distribution
#
# - Shows the distribution of hedging error $( V_T - Z_T )$
# - Includes both histogram and KDE (smoothed density curve)
# - Good models should concentrate around 0 and avoid large negative errors.
#
# ---

# %%
import numpy as np, matplotlib.pyplot as plt, seaborn as sns

# Load the file that matches test-set shapes
data = np.load("results/hedging_eval_test.npz")      # “_test”

V_T_np = data["V_T"]      # hedged portfolio, shape (2 000,)
Z_T_np = data["Z_T"]      # true pay-off,     shape (2 000,)

# sanity check
assert V_T_np.shape == Z_T_np.shape, \
       f"Shape mismatch: V_T {V_T_np.shape} vs Z_T {Z_T_np.shape}"

errors = V_T_np - Z_T_np

max_pts = 50_000
if V_T_np.size > max_pts:
    idx = np.random.choice(V_T_np.size, max_pts, replace=False)
    V_sm, Z_sm, err_sm = V_T_np[idx], Z_T_np[idx], errors[idx]
else:
    V_sm, Z_sm, err_sm = V_T_np, Z_T_np, errors

# Histogram
plt.figure(figsize=(10,4))
plt.hist(V_T_np, bins=50, alpha=0.6, label='Hedged $V_T$')
plt.hist(Z_T_np, bins=50, alpha=0.6, label='Payoff $Z_T$')
plt.legend(); plt.grid(True)
plt.title("Distribution of $V_T$ vs $Z_T$"); plt.tight_layout(); plt.show()

# Scatter (hexbin)
plt.figure(figsize=(6,6))
plt.hexbin(Z_sm, V_sm, gridsize=80, bins='log')
lim = [0, max(Z_sm.max(), V_sm.max())]
plt.plot(lim, lim, 'r--'); plt.xlim(lim); plt.ylim(lim)
plt.xlabel("$Z_T$"); plt.ylabel("$V_T$")
plt.title("Hedging Effectiveness")
plt.colorbar(label="log10(count)")
plt.tight_layout(); plt.show()

# Error distribution
plt.figure(figsize=(8,4))
sns.histplot(errors, bins=50, kde=False, color="steelblue")
sns.kdeplot(err_sm, color="orange", label="KDE (sample)")
plt.grid(True); plt.legend()
plt.title("Hedging Error $V_T - Z_T$")
plt.tight_layout(); plt.show()

# %%
itm_mask = Z_T_np > 0
mae_itm  = np.mean(np.abs(errors[itm_mask]))
rel_err  = np.mean(np.abs(errors[itm_mask]) / Z_T_np[itm_mask])
print("ITM-only MAE :", mae_itm)
print("Mean relative error (ITM):", rel_err)
# Out:
# ITM-only MAE : 1.5380304
# Mean relative error (ITM): 0.19170882

# %% [markdown]
# ## 4.3 Quantitative Evaluation
#
# We focus on **In-The-Money (ITM)** cases only — when the option actually had non-zero payoff:
#
# - **Mean Absolute Error (ITM)**:
#   $$[
#   \text{MAE}_{\text{ITM}} = \mathbb{E}[|V_T - Z_T| \,|\, Z_T > 0]
#   $$
#   → **1.538**
#
# - **Mean Relative Error (ITM)**:
#   $$
#   \mathbb{E}\left[\frac{|V_T - Z_T|}{Z_T} \,\Big|\, Z_T > 0 \right]
#   $$
#   → **19.17%**
#
# ---
#
# ## 4.4 Interpretation
#
# - The model replicates the payoff quite accurately across a wide range of market scenarios.
# - Most hedging errors fall near zero, with a small negative skew due to conservative risk-averse CVaR training.
# - The scatter plot shows very high correlation between predicted and true outcomes.
# - Relative error under 20% on ITM paths suggests solid performance under non-ideal market conditions.
#
# ---
#
# ## Summary
#
# This notebook demonstrated:
# - The effectiveness of the Deep Hedging model
# - Performance visualization through insightful plots
# - Quantitative validation using MAE and relative error
